# %% [markdown]
# # Sentinel-1 processed SAR visualization

# %%
import os
import rasterio
from rasterio.plot import show 

home_path = os.path.expanduser('~/gcp_projects/SAR-Processing')
sar_path = 'data/processed/stanlow/S1A__IW___D_20230514T062300_VH_sigma0-rtc_db.tif'
sar_path = os.path.join(home_path, sar_path)

sar_img = rasterio.open(sar_path)
show(sar_img)
# Out:
# <AxesSubplot:>

# %%
sar_stack = sar_prod.stack([SLOPE, VH])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_11778/1204732600.py in <module>
# ----> 1 sar_stack = sar_prod.stack([SLOPE, VH])
#
# ~/mambaforge/envs/esa_snap/lib/python3.7/site-packages/eoreader/products/product.py in stack(self, bands, resolution, size, stack_path, save_as_int, **kwargs)
#    1437
#    1438         # Create the analysis stack
# -> 1439         band_dict = self.load(bands, resolution=resolution, size=size, **kwargs)
#    1440
#    1441         # Convert into dataset with str as names
#
# ~/mambaforge/envs/esa_snap/lib/python3.7/site-packages/eoreader/products/product.py in load(self, bands, resolution, size, **kwargs)
#     908         # Load bands (only once ! and convert the bands to be loaded to correct format)
#     909         unique_bands = list(set(to_band(bands)))
# ...
